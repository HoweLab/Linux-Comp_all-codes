# %%
#write script to find all of the files that we have alread run caiman on and load the object, recalculat the dff_f with the corrrect window, and then resave the hd5
#and the mat file so that the mat file also has cleaner transients. 
import os 
import glob
from caiman.source_extraction.cnmf.utilities import detrend_df_f
from caiman.source_extraction.cnmf.cnmf import load_CNMF
import time as t
import datetime as dt
from scipy.io import savemat
import numpy as np
from caiman.utils.visualization import get_contours
import caiman as cm

t1 = dt.datetime.now()
timeStamp = str(t1.year)  + '_' + str(t1.month) + '_' + str(t1.day) + '_' + str(t1.hour) + '_' + str(t1.minute)
print(timeStamp)
rootDirs = ['/mnt/Brenna_Feb2023']
pattern = 'caimanEval_Python.hdf5'
bigList = []
matList = []
for cDir in range(len(rootDirs)):
    rootDir = rootDirs[cDir]

    folderList = []
    for path in glob.glob(f'{(rootDir)}/*/**/', recursive=True):
        folderList.append(path)

    # folderList = [folder for folder in files if os.path.isdir(os.path.join(rootDir, folder)) == True]
    for cFol in range(len(folderList)):
        filesIn = os.listdir(os.path.join(rootDir, folderList[cFol]))

        for cF in range(len(filesIn)):
            currentPath = os.path.join(rootDir, folderList[cFol], filesIn[cF])
            if pattern.lower() in filesIn[cF].lower():
                bigList.append(os.path.join(rootDir, folderList[cFol], filesIn[cF]))
# Out:
# 2023_4_7_14_7

# %%
def saveCaimain2MatDifferent(estimates, saveLocation, outName, dims):
  from caiman.utils.visualization import get_contours
  fields = vars(estimates)
  matInfo ={}
  #dictionary of vars that we are actually interested in taking from the CNMF object 
  varsWeWant = {
          'C':'temporal_components', 
          'b':'bckgrnd_spatial', 
          'f':'temporal_bckgrnd_components', 
          'YrA':'residual_components', 
          'F_dff':'dFF',
          # 'idx_components':'good_components',
          # 'idx_components_bad':'bad_components',
          'SNR_comp':'SnR',
          'r_values':'rVals',
          'cnn_preds':'cnn'
          }
  
  #making the sparse matrix into a 3D matrix that matlab will actually be able to parse
  numRois = np.shape(estimates.A)[1]
  spatialComponents = np.zeros([dims[0], dims[1], numRois])
  for cROI in range(np.shape(estimates.A)[1]):
    #changed cROI - 1 to cROI
    roiArray = np.reshape(estimates.A[:,cROI].toarray(), dims, order='F')
    spatialComponents[:,:,cROI] = roiArray

  #using an internal caiman function to extract the contours of our ROIs
  caimanContours = get_contours(estimates.A, dims)

  #manually add a couple of variabeles to our matInfo dictionary
  matInfo['ica_segments'] = spatialComponents 
  matInfo['ROIContours'] = caimanContours

  #loop through the vars we want and save the corresponding variables into our matInfo dictionary
  for cK in varsWeWant.keys():
    matInfo[varsWeWant[cK]] = fields[cK]
  #use the scipy.io function to save out a .mat file from a dicionary input variable
  savemat(os.path.join(saveLocation, outName + '.mat'), matInfo)

  return matInfo

# %%
for cS in bigList:
    caimanSession = load_CNMF(cS)

    currentFolder = os.path.dirname(cS)
    currentFile = os.path.basename(cS)
    estimates = caimanSession.estimates
    print("Working on: ", os.path.join(currentFolder, currentFile))
    print("calculating df_f...")
    estimates.F_dff = detrend_df_f(estimates.A, estimates.b, estimates.C, estimates.f, YrA=estimates.YrA, quantileMin = 8, frames_window = 500)

    print("Saving new files...")
    dictVersionOfMat = saveCaimain2MatDifferent(caimanSession.estimates,currentFolder, currentFile + '_caimanEval_newDFF_calc' + timeStamp, caimanSession.dims)
    caimanSession.save(os.path.join(currentFolder, currentFile + '_caimanEval_Python_newDFF_calc.hdf5'))
# Out:
# Working on:  /mnt/Brenna_Feb2023/TdTG7_18/TdTG7_18_007/field1_gui/caimanOuputs_2023_3_15_1_20/ConcatenatedMovie_MC_reg_caimanEval_Python.hdf5
# calculating df_f...
# Saving new files...
# Working on:  /mnt/Brenna_Feb2023/TdTG7_18/TdTG7_18_007/field1_track/caimanOuputs_2023_3_15_1_35/ConcatenatedMovie_MC_reg_caimanEval_Python.hdf5
# calculating df_f...
# Saving new files...
# Working on:  /mnt/Brenna_Feb2023/TdTG7_18/TdTG7_18_007/field2_track/caimanOuputs_2023_3_15_3_26/ConcatenatedMovie_MC_reg_caimanEval_Python.hdf5
# calculating df_f...
# Saving new files...
# Working on:  /mnt/Brenna_Feb2023/TdTG7_18/TdTG7_18_008/field1_gui/caimanOuputs_2023_3_14_22_22/ConcatenatedMovie_MC_reg_caimanEval_Python.hdf5
# calculating df_f...
# Saving new files...
# Working on:  /mnt/Brenna_Feb2023/TdTG7_18/TdTG7_18_008/field1_gui/caimanOuputs_2023_3_17_14_59/ConcatenatedMovie_MC_reg_caimanEval_Python.hdf5
# calculating df_f...
# Saving new files...
# Working on:  /mnt/Brenna_Feb2023/TdTG7_18/TdTG7_18_008/field1_gui/caimanOuputs_2023_3_20_11_30/ConcatenatedMovie_MC_reg_caimanEval_Python.hdf5
# calculating df_f...
# Saving new files...
# Working on:  /mnt/Brenna_Feb2023/TdTG7_18/TdTG7_18_008/field1_gui/caimanOuputs_2023_3_20_15_7/ConcatenatedMovie_MC_reg_caimanEval_Python.hdf5
# calculating df_f...
# Saving new files...
# Working on:  /mnt/Brenna_Feb2023/TdTG7_18/TdTG7_18_008/field1_gui/caimanOuputs_2023_3_20_16_37/ConcatenatedMovie_MC_reg_caimanEval_Python.hdf5
# calculating df_f...
# Saving new files...
# Working on:  /mnt/Brenna_Feb2023/TdTG7_18/TdTG7_18_008/field1_track/caimanOuputs_2023_3_14_22_38/ConcatenatedMovie_MC_reg_caimanEval_Python.hdf5
# calculating df_f...
# Saving new files...
# Working on:  /mnt/Brenna_Feb2023/TdTG7_18/TdTG7_18_009/field1_gui/caimanOuputs_2023_3_14_16_53/ConcatenatedMovie_MC_reg_caimanEval_Python.hdf5
# calculating df_f...
# Saving new files...
# Working on:  /mnt/Brenna_Feb2023/TdTG7_18/TdTG7_18_009/field1_track/caimanOuputs_2023_3_14_17_9/ConcatenatedMovie_MC_reg_caimanEval_Python.hdf5
# calculating df_f...
# Saving new files...
# Working on:  /mnt/Brenna_Feb2023/TdTG7_18/TdTG7_18_009/field2_gui/caimanOuputs_2023_3_14_19_9/ConcatenatedMovie_MC_reg_caimanEval_Python.hdf5
# calculating df_f...
# Saving new files...
# Working on:  /mnt/Brenna_Feb2023/TdTG7_18/TdTG7_18_009/field2_track/caimanOuputs_2023_3_14_19_24/ConcatenatedMovie_MC_reg_caimanEval_Python.hdf5
# calculating df_f...
# Saving new files...
# Working on:  /mnt/Brenna_Feb2023/TdTG7_18/TdTG7_18_010/field1_gui/caimanOuputs_2023_3_14_15_21/ConcatenatedMovie_MC_reg_caimanEval_Python.hdf5
# calculating df_f...
# Saving new files...
# Working on:  /mnt/Brenna_Feb2023/TdTG7_18/TdTG7_18_010/field1_track/caimanOuputs_2023_3_14_15_33/ConcatenatedMovie_MC_reg_caimanEval_Python.hdf5
# calculating df_f...
# Saving new files...
# Working on:  /mnt/Brenna_Feb2023/TdTG7_18/TdTG7_18_012/field1_gui/caimanOuputs_2023_3_14_14_2/ConcatenatedMovie_MC_reg_caimanEval_Python.hdf5
# calculating df_f...
# Saving new files...
# Working on:  /mnt/Brenna_Feb2023/TdTG7_18/TdTG7_18_012/field1_track/caimanOuputs_2023_3_14_14_16/ConcatenatedMovie_MC_reg_caimanEval_Python.hdf5
# calculating df_f...
# Saving new files...
# Working on:  /mnt/Brenna_Feb2023/TdTG7_18/TdTG7_18_012/field2_gui/caimanOuputs_2023_3_14_14_30/ConcatenatedMovie_MC_reg_caimanEval_Python.hdf5
# calculating df_f...
# Saving new files...
# Working on:  /mnt/Brenna_Feb2023/TdTG7_18/TdTG7_18_012/field2_track/caimanOuputs_2023_3_14_14_44/ConcatenatedMovie_MC_reg_caimanEval_Python.hdf5
# calculating df_f...
# Saving new files...
# Working on:  /mnt/Brenna_Feb2023/TdTG7_18/TdTG7_18_014/field1_track/caimanOuputs_2023_3_14_11_46/ConcatenatedMovie_MC_reg_caimanEval_Python.hdf5
# calculating df_f...
# Saving new files...
# Working on:  /mnt/Brenna_Feb2023/TdTG7_18/TdTG7_18_014/field2_gui/caimanOuputs_2023_3_14_13_46/ConcatenatedMovie_MC_reg_caimanEval_Python.hdf5
# calculating df_f...
# Saving new files...
# Working on:  /mnt/Brenna_Feb2023/TdTG7_18/TdTG7_18_018/field1_gui/caimanOuputs_2023_3_13_23_52/ConcatenatedMovie_MC_reg_caimanEval_Python.hdf5
# calculating df_f...
# Saving new files...
# Working on:  /mnt/Brenna_Feb2023/TdTG7_18/TdTG7_18_018/field1_track/caimanOuputs_2023_3_14_0_3/ConcatenatedMovie_MC_reg_caimanEval_Python.hdf5
# calculating df_f...
# Saving new files...
# Working on:  /mnt/Brenna_Feb2023/TdTG7_18/TdTG7_18_018/field2_gui/caimanOuputs_2023_3_14_2_40/ConcatenatedMovie_MC_reg_caimanEval_Python.hdf5
# calculating df_f...
# Saving new files...
# Working on:  /mnt/Brenna_Feb2023/TdTG7_18/TdTG7_18_018/field2_track/caimanOuputs_2023_3_14_2_52/ConcatenatedMovie_MC_reg_caimanEval_Python.hdf5
# calculating df_f...
# Saving new files...
# Working on:  /mnt/Brenna_Feb2023/TdTG7_18/TdTG7_18_025/field1_track/caimanOuputs_2023_3_13_19_36/ConcatenatedMovie_MC_reg_caimanEval_Python.hdf5
# calculating df_f...
# Saving new files...
# Working on:  /mnt/Brenna_Feb2023/TdTG7_18/TdTG7_18_025/field2_gui/caimanOuputs_2023_3_13_21_58/ConcatenatedMovie_MC_reg_caimanEval_Python.hdf5
# calculating df_f...
# Saving new files...
# Working on:  /mnt/Brenna_Feb2023/TdTG7_18/TdTG7_18_025/field2_track/caimanOuputs_2023_3_13_22_12/ConcatenatedMovie_MC_reg_caimanEval_Python.hdf5
# calculating df_f...
# Saving new files...
# Working on:  /mnt/Brenna_Feb2023/TdTG7_18/TdTG7_18_026/field1_gui/caimanOuputs_2023_3_13_17_37/ConcatenatedMovie_MC_reg_caimanEval_Python.hdf5
# calculating df_f...
# Saving new files...
# Working on:  /mnt/Brenna_Feb2023/TdTG7_18/TdTG7_18_026/field1_track/caimanOuputs_2023_3_13_17_50/ConcatenatedMovie_MC_reg_caimanEval_Python.hdf5
# calculating df_f...
# Saving new files...
# Working on:  /mnt/Brenna_Feb2023/TdTG7_18/TdTG7_18_026/field1_track/caimanOuputs_2023_3_8_17_43/ConcatenatedMovie_MC_reg_caimanEval_Python.hdf5
# calculating df_f...
# Saving new files...
# Working on:  /mnt/Brenna_Feb2023/TdTG7_18/TdTG7_18_026/field2_gui/caimanOuputs_2023_3_13_19_21/ConcatenatedMovie_MC_reg_caimanEval_Python.hdf5
# calculating df_f...
# Saving new files...
# Working on:  /mnt/Brenna_Feb2023/TdTG7_18/TdTG7_18_027/field1_gui/caimanOuputs_2023_2_24_12_31/ConcatenatedMovie_MC_reg_caimanEval_Python.hdf5
# calculating df_f...
# Saving new files...
# Working on:  /mnt/Brenna_Feb2023/TdTG7_18/TdTG7_18_027/field1_gui/caimanOuputs_2023_2_24_12_6/ConcatenatedMovie_MC_reg_caimanEval_Python.hdf5
# calculating df_f...
# Saving new files...
# Working on:  /mnt/Brenna_Feb2023/TdTG7_18/TdTG7_18_027/field2_track/caimanOuputs_2023_3_13_15_56/ConcatenatedMovie_MC_reg_caimanEval_Python.hdf5
# calculating df_f...
# Saving new files...
# Working on:  /mnt/Brenna_Feb2023/TdTG7_18/TdTG7_18_028/field1_gui/caimanOuputs_2023_4_7_9_39/ConcatenatedMovie_MC_reg_caimanEval_Python.hdf5
# calculating df_f...
# Saving new files...
# Working on:  /mnt/Brenna_Feb2023/TdTG7_18/TdTG7_18_029/field1_gui/caimanOuputs_2023_4_2_14_50/ConcatenatedMovie_MC_reg_caimanEval_Python.hdf5
# calculating df_f...
# Saving new files...
# Working on:  /mnt/Brenna_Feb2023/TdTG7_18/TdTG7_18_029/field1_track/caimanOuputs_2023_4_2_15_3/ConcatenatedMovie_MC_reg_caimanEval_Python.hdf5
# calculating df_f...
# Saving new files...
# Working on:  /mnt/Brenna_Feb2023/TdTG7_19/20230306/field1_gui/caimanOuputs_2023_4_3_22_52/ConcatenatedMovie_MC_reg_caimanEval_Python.hdf5
# calculating df_f...
# Saving new files...
# Working on:  /mnt/Brenna_Feb2023/TdTG7_19/20230306/field1_track/caimanOuputs_2023_4_3_23_5/ConcatenatedMovie_MC_reg_caimanEval_Python.hdf5
# calculating df_f...
# Saving new files...
# Working on:  /mnt/Brenna_Feb2023/TdTG7_19/20230306/field2_gui/caimanOuputs_2023_4_3_23_58/ConcatenatedMovie_MC_reg_caimanEval_Python.hdf5
# calculating df_f...
# Saving new files...
# Working on:  /mnt/Brenna_Feb2023/TdTG7_19/20230306/field2_track/caimanOuputs_2023_4_4_0_11/ConcatenatedMovie_MC_reg_caimanEval_Python.hdf5
# calculating df_f...
# Saving new files...
# Working on:  /mnt/Brenna_Feb2023/TdTG7_19/20230307/field1_track/caimanOuputs_2023_4_3_22_4/ConcatenatedMovie_MC_reg_caimanEval_Python.hdf5
# calculating df_f...
# Saving new files...
# Working on:  /mnt/Brenna_Feb2023/TdTG7_19/20230307/field2_track/caimanOuputs_2023_4_3_22_32/ConcatenatedMovie_MC_reg_caimanEval_Python.hdf5
# calculating df_f...
# Saving new files...
# Working on:  /mnt/Brenna_Feb2023/TdTG7_19/20230308/field1_gui/caimanOuputs_2023_4_3_20_55/ConcatenatedMovie_MC_reg_caimanEval_Python.hdf5
# calculating df_f...
# Saving new files...
# Working on:  /mnt/Brenna_Feb2023/TdTG7_19/20230308/field1_track/caimanOuputs_2023_4_3_21_8/ConcatenatedMovie_MC_reg_caimanEval_Python.hdf5
# calculating df_f...
# Saving new files...
# Working on:  /mnt/Brenna_Feb2023/TdTG7_19/20230309/field1_gui/caimanOuputs_2023_4_3_19_4/ConcatenatedMovie_MC_reg_caimanEval_Python.hdf5
# calculating df_f...
# Saving new files...
# Working on:  /mnt/Brenna_Feb2023/TdTG7_19/20230309/field1_track/caimanOuputs_2023_4_3_19_12/ConcatenatedMovie_MC_reg_caimanEval_Python.hdf5
# calculating df_f...
# Saving new files...
# Working on:  /mnt/Brenna_Feb2023/TdTG7_19/20230310/field1_gui/caimanOuputs_2023_4_3_17_2/ConcatenatedMovie_MC_reg_caimanEval_Python.hdf5
# calculating df_f...
# Saving new files...
# Working on:  /mnt/Brenna_Feb2023/TdTG7_19/20230310/field1_track/caimanOuputs_2023_4_3_17_12/ConcatenatedMovie_MC_reg_caimanEval_Python.hdf5
# calculating df_f...
# Saving new files...
# Working on:  /mnt/Brenna_Feb2023/TdTG7_19/20230312/field1_track/caimanOuputs_2023_4_3_15_18/ConcatenatedMovie_MC_reg_caimanEval_Python.hdf5
# calculating df_f...
# Saving new files...
# Working on:  /mnt/Brenna_Feb2023/TdTG7_19/20230314/field1_gui/caimanOuputs_2023_4_3_11_5/ConcatenatedMovie_MC_reg_caimanEval_Python.hdf5
# calculating df_f...
# Saving new files...
# Working on:  /mnt/Brenna_Feb2023/TdTG7_19/20230314/field1_track/caimanOuputs_2023_4_3_11_18/ConcatenatedMovie_MC_reg_caimanEval_Python.hdf5
# calculating df_f...
# Saving new files...
# Working on:  /mnt/Brenna_Feb2023/TdTG7_19/20230316/field1_gui/caimanOuputs_2023_4_3_8_11/ConcatenatedMovie_MC_reg_caimanEval_Python.hdf5
# calculating df_f...
# Saving new files...
# Working on:  /mnt/Brenna_Feb2023/TdTG7_19/20230316/field1_track/caimanOuputs_2023_4_3_8_23/ConcatenatedMovie_MC_reg_caimanEval_Python.hdf5
# calculating df_f...
# Saving new files...
# Working on:  /mnt/Brenna_Feb2023/TdTG7_19/20230316/field2_gui/caimanOuputs_2023_4_3_9_48/ConcatenatedMovie_MC_reg_caimanEval_Python.hdf5
# calculating df_f...
# Saving new files...
# Working on:  /mnt/Brenna_Feb2023/TdTG7_19/20230316/field2_track/caimanOuputs_2023_4_3_10_1/ConcatenatedMovie_MC_reg_caimanEval_Python.hdf5
# calculating df_f...
# Saving new files...
# Working on:  /mnt/Brenna_Feb2023/TdTG7_19/20230317/field1_gui/caimanOuputs_2023_4_3_2_44/ConcatenatedMovie_MC_reg_caimanEval_Python.hdf5
# calculating df_f...
# Saving new files...
# Working on:  /mnt/Brenna_Feb2023/TdTG7_19/20230317/field1_track/caimanOuputs_2023_4_3_2_59/ConcatenatedMovie_MC_reg_caimanEval_Python.hdf5
# calculating df_f...
# Saving new files...
# Working on:  /mnt/Brenna_Feb2023/TdTG7_19/20230321/field1_track_aftergain/caimanOuputs_2023_4_3_1_32/ConcatenatedMovie_MC_reg_caimanEval_Python.hdf5
# calculating df_f...
# Saving new files...
# Working on:  /mnt/Brenna_Feb2023/TdTG7_19/20230321/field1_track_beforegain/caimanOuputs_2023_4_3_1_47/ConcatenatedMovie_MC_reg_caimanEval_Python.hdf5
# calculating df_f...
# Saving new files...
# Working on:  /mnt/Brenna_Feb2023/TdTG7_19/20230324/gui/caimanOuputs_2023_4_2_22_58/ConcatenatedMovie_MC_reg_caimanEval_Python.hdf5
# calculating df_f...
# Saving new files...
# Working on:  /mnt/Brenna_Feb2023/TdTG7_19/20230324/track_aftergain/caimanOuputs_2023_4_2_23_12/ConcatenatedMovie_MC_reg_caimanEval_Python.hdf5
# calculating df_f...
# Saving new files...
# Working on:  /mnt/Brenna_Feb2023/TdTG7_19/20230326/gui/caimanOuputs_2023_4_2_19_54/ConcatenatedMovie_MC_reg_caimanEval_Python.hdf5
# calculating df_f...
# Saving new files...
# Working on:  /mnt/Brenna_Feb2023/TdTG7_19/20230326/track_aftergain/caimanOuputs_2023_4_2_20_8/ConcatenatedMovie_MC_reg_caimanEval_Python.hdf5
# calculating df_f...
# Saving new files...
# Working on:  /mnt/Brenna_Feb2023/TdTG7_19/20230326/track_beforegain/caimanOuputs_2023_4_2_22_27/ConcatenatedMovie_MC_reg_caimanEval_Python.hdf5
# calculating df_f...
# Saving new files...
# Working on:  /mnt/Brenna_Feb2023/TdTG7_19/20230327/gui/caimanOuputs_2023_4_2_16_1/ConcatenatedMovie_MC_reg_caimanEval_Python.hdf5
# calculating df_f...
# Saving new files...
# Working on:  /mnt/Brenna_Feb2023/TdTG7_19/20230327/track_aftergain/caimanOuputs_2023_4_2_16_15/ConcatenatedMovie_MC_reg_caimanEval_Python.hdf5
# calculating df_f...
# Saving new files...
# Working on:  /mnt/Brenna_Feb2023/TdTG7_19/20230327/track_beforegain/caimanOuputs_2023_4_2_18_9/ConcatenatedMovie_MC_reg_caimanEval_Python.hdf5
# calculating df_f...
# Saving new files...
